# %% [markdown]
# # Assignment 7 :
#
#
# ### For image1 use Sobel operators to find the horizontal and vertical edges in the image. Repeat the steps, but with the original image smoothed using a 5 × 5 averaging kernel prior to edge detection. Show the results and write your observations.
#
#
#
#
#
# ### Use Canny edge detector on image1. Use different thresholds and analyze your results.

# %% [markdown]
# # 1- Import Libraries

# %%
import numpy as np # numpy
import matplotlib.pyplot as plt # matplotlib
import cv2 # opencv

# %% [markdown]
# # 2- Read the img and turn it into grayscale

# %%
img = cv2.imread('1(2).tif') # read image
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # BGR ==> GRAY

# %% [markdown]
# # 3- Function to display image

# %%
def show_image(img):
    """
    This Method to disply image in 10*10 scale
    """
    fig = plt.figure(figsize=(10,10))
    ax  = fig.add_subplot(1,1,1, xticks=[], yticks=[])
    ax.imshow(img, cmap='gray')

# %% [markdown]
# # 4- Display the image and image shape

# %%
show_image(img)

# %%
img.shape
# Out:
# (834, 1114, 3)

# %%
gray.shape
# Out:
# (834, 1114)

# %%
img.size
# Out:
# 2787228

# %%
gray.size
# Out:
# 929076

# %% [markdown]
# # We notice the reducing in image size between the 3 channels image and one channel image

# %% [markdown]
# # 5- Sobel edge detection without Blur

# %%
sobelX = cv2.Sobel(src=gray, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5)  # X edge detection

sobelY = cv2.Sobel(src=gray, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5)  # Y edge detection

# %%
show_image(sobelX)

# %%
show_image(sobelY)

# %%
sobel = sobelX +sobelY # combine them togather
show_image(sobel)

# %% [markdown]
# # 6- Sobel edge detection with Blur

# %%
blur = cv2.blur(gray, (5,5))

# %%
show_image(blur)

# %%
sobelX = cv2.Sobel(src=blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5)  # X edge detection

sobelY = cv2.Sobel(src=blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5)  # Y edge detection

# %%
show_image(sobelX)

# %%
show_image(sobelY)

# %%
sobel = sobelX +sobelY # combine them togather
show_image(sobel)

# %% [markdown]
# # 7- Write the observation of previous two experiment

# %% [markdown]
# # What I notice that the image become less sharp and it is ignore small details and focus on the shape of building in general

# %% [markdown]
# # 8- Canny edge detection without Blur

# %%
min_threshs = [75,100, 128, 150, 175, 200] #list of min threshs
max_threshs = [200, 210,220,230,240,250]#list of max threshs

# %%
for i in range(len(min_threshs)):
    Canny = cv2.Canny(gray, min_threshs[i],max_threshs[i])
    show_image(Canny)

# %% [markdown]
# # 9- Canny edge detection with Blur

# %%
for i in range(len(min_threshs)):
    Canny = cv2.Canny(blur, min_threshs[i],max_threshs[i])
    show_image(Canny)

# %% [markdown]
# # 10- Analysis of results

# %% [markdown]
# # The Canny expermint we do two steps first define list of 6 min and max threshold and try it on the image one without blur and the second one with blur
#
#
# # The result as obvious the one without blur has more details as the second one with blur,
#
# # When you do  not apply blur you should choose greater values of threshes, but that will lead to reduce the neccassoory observations in your image.
#
# # When you do apply blur make shur you choose small threshs values beacuse the best result with blur was the first one (75,200)
#
# # So make a blur and start with small threshs values.
